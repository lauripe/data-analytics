# %% [markdown]
# # Assignment 2
# Lauri Pessi | bft860
#
# ## Dataset: titanic.xlsx

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, math

# Fetch the data and take a peek what's inside
df = pd.read_excel('http://myy.haaga-helia.fi/~menetelmat/Data-analytiikka/Teaching/titanic.xlsx')

n = int(df.shape[0])
print('Rows: ' + str(n))
print('Cols: ' + str(df.shape[1]))

df.head()
# Out:
# Rows: 1309
# Cols: 14
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Let's check the ticket class and sex effect on surival rate
pd.crosstab([df.pclass, df.sex], df.survived, normalize='index').style.format('{:.0%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_67da4_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pclass</th>
#       <th class="index_name level1" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67da4_level0_row0" class="row_heading level0 row0" rowspan="2">1</th>
#       <th id="T_67da4_level1_row0" class="row_heading level1 row0" >female</th>
#       <td id="T_67da4_row0_col0" class="data row0 col0" >3%</td>
#       <td id="T_67da4_row0_col1" class="data row0 col1" >97%</td>
#     </tr>
#     <tr>
#       <th id="T_67da4_level1_row1" class="row_heading level1 row1" >male</th>
# ...
